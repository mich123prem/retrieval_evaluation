# %% [markdown]
# ## Just an example of a matplotlib plot

# %%
import matplotlib.pyplot as plt


x=[0, 1, 2, 3]
y1=[4, 1.5, 1.1, 0]
y2=[3, 1.4, 1.0, 0]
lbl1="lbl1"
lbl2="lbl2"
plt.plot(x,y1, linestyle="-", label=lbl1)
plt.plot(x, y2, linestyle="-.", label=lbl2)
plt.legend()
plt.show()
